# %%
"""
MASTER EQUATION JAX TEST SUITE — Configuration & Versioning
============================================================
All parameters, seeds, and version metadata in one place.
Change parameters here → everything downstream updates.

David Lowe (POF 2828) | March 2026
"""

# %%
# Physical constants (natural units: c = hbar = 1)
M_CHI = 1e-33           # eV — chi mass ~ H_0
XI_COUPLING = 1e3       # non-minimal gravity coupling (Cassini: |xi| < 1e5)
LAMBDA_SELF = 0.1       # chi^4 self-coupling (lambda > 0 for stability)
KAPPA_0 = 1.0           # 8*pi*G/c^4 (normalized)
BETA_GRACE = 0.3        # grace coupling constant
EPSILON_UV = 1e-10       # UV cutoff for grace source

# %%
# 10-variable structure
N_VARS = 10
VAR_NAMES = ["Grace", "Matter", "Energy", "Entropy", "Time",
             "Knowledge", "Relation", "Quantum", "Faith", "Coherence"]
VAR_SHORT = ["G", "M", "E", "S", "T", "K", "R", "Q", "F", "C"]

# %%
# Symmetry pairs (index_a, index_b)
SYMMETRY_PAIRS = [(0, 4), (3, 8), (2, 5), (1, 7), (6, 9)]
PAIR_LABELS = ["G<->T", "S<->F", "E<->K", "M<->Q", "R<->C"]

# %%
# Variable weights (kinetic contribution)
VAR_WEIGHTS_DEFAULT = [1.0, 0.8, 1.2, 0.6, 1.0, 0.7, 0.5, 0.9, 1.1, 1.3]

# %%
# Pair coupling strength (subcritical; stability boundary ~0.64)
PAIR_STRENGTH = 0.45

# %%
# Integration parameters
RK4_DT = 0.005
INTEGRATION_T_SPAN = (0.0, 5.0)

# %%
# Monte Carlo
MC_SAMPLES = 100_000
MC_FIELD_SAMPLES = 10_000

# %%
# Random seeds (deterministic)
SEED_PRIMARY = 2828
SEED_SECONDARY = 42

# %%
# Hubble parameters (Test 1B)
H0_LOCAL = 73.5          # km/s/Mpc (SH0ES)
H0_CMB = 67.4            # km/s/Mpc (Planck)
Z_CMB = 1100.0           # CMB redshift

# %%
# Coherence model (Test 3)
SIGMA_DECAY = 0.05       # entropy production rate
T_MORAL_DEFAULT = 1.0    # moral temperature

# %%
# Version tracking
FRAMEWORK_VERSION = "2.0.0-modular"
